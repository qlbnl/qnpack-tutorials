# %% [markdown]
# # First All-photonic Repeater Network
#
# This example will demonstrate how to use QNPack to simulate a quantum network repeater chain using a single quantum repeater (QR).
#
# <img src="./images/ape_network.png" width="75%"><br>

# %% [markdown]
# The APE repeater network is consisted of quantum end nodes (Q-nodes), quantum repeaters (QRs), Bell-State-Measurement nodes (BSM),  classical and quantum channels. In the beginning, the emitter qubit in APE QRs will emit Repeater Graph State (RGS) following a predefined circuit. Since each APE QR generates and transmits RGS photonic qubits sequentially in a predefined manner, each photonic qubit arriving at a BSM-node in the designated time interval can be identified as either a leaf, 1st-level core or 2nd-level core qubit. We make the following assumptions of photon loss and noise:
# 1. The sources of photon loss include collection efficiency, quantum frequency conversion efficiency, fiber attenuation, and detector efficiency.
# 2. The only noises are emitter (quantum dot) decoherence in APE QR and memory (nuclear spin) decoherence in Q-nodes.
#
# In the code below, we first demonstrate how to use QNPack to simulate a quantum network repeater chain under an ideal situation without loss and noise.

# %%
from qnpack.APE.allphotonic import APESimulation

fixed_params = {
    "network": {"photon_loss": 0},
    "emitter":{"emitter_T2":0, "memory_T2":0,"QFC_loss":0},    
    "rgs":{"num_branches_half":2,"b0":1,"b1":0} 
}
varying_params = {
    "num_repeaters": [1,2,3,4],
    "distance": [10]
}

sim = APESimulation(fixed_params=fixed_params,
                    varying_params=varying_params,
                    iterations=30,
                    min_successful=0,
                    parameter_file="parameters/scenario1.yml",
                    output_dir="results")
data=sim.start()
sim.plot(final_data=data, show_theo_rate=True, x_axis1="num_repeaters", y_axis1="sim_rate", xlabel1="Number of repeaters", ylabel1="Rate (Hz)",
     label_param1="distance", title1="Rate vs Number of repeaters",
     x_axis2="num_repeaters", y_axis2="fidelity", xlabel2="Number of repeaters", ylabel2="Fidelity",
     label_param2="distance", title2="Fidelity vs Number of repeaters"
     )
sim.finalize()
# Out:
# /home/ottochan/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Updated network.photon_loss: 0.2 -> 0
# Updated emitter.emitter_T2: 3000 -> 0
# Updated emitter.memory_T2: 20000000.0 -> 0
# Updated emitter.QFC_loss: 0 -> 0
# Updated rgs.num_branches_half: 2 -> 2
# Updated rgs.b0: 2 -> 1
# Updated rgs.b1: 1 -> 0
# self.cfg.network.photon_loss 0
# 15:46:52 qnpack.APE.allphotonic INFO Configuration:
# bsm:
#   coupling_efficiency: 0.9
#   detection_window: 3
#   detector_wait_factor: 1.05
#   max_emission_retries: 90
#   system_delay: 0
#   timeout: 40
# clock:
#   HZ: 1000000
#   max_ticks: -1
# emitter:
#   CZ_duration: 100
#   EMIT_PHOTON_duration: 2
#   H_duration: 1
#   INIT_duration: 1
#   MEASURE_duration: 20
#   QFC_loss: 0
#   collection_eff: 0.997
#   detector_eff: 1
#   emitter_T1: 0
#   emitter_T2: 0
#   mem_measure: forced
#   memory_T1: 0
#   memory_T2: 0
#   num_matter_qubits: 7
#   photon_emission_buffer: 1
# network:
#   attenuation_length: 22
#   c_lightspeed: 200000
#   channel_depolar_rate: 0.1
#   init_photon_loss: 0
#   node_c_pos: 0
#   photon_loss: 0
#   proto_sched: 1
#   q_lightspeed: 200000
# rgs:
#   b0: 1
#   b1: 0
#   num_branches_half: 2
# sim:
#   debug: false
#   is_one_end_noise: false
#   iterations: 10
#   min_successful: 0
#   noiseless: false
#   starting_seed: 500000
# spd:
#   detection_window: 2
#
# 15:46:52 qnpack.APE.allphotonic INFO Running simulation with parameters: {'num_repeaters': [1, 2, 3, 4], 'distance': [10]}
# 15:46:52 qnpack.APE.allphotonic INFO Fixed parameters: {'network': {'photon_loss': 0}, 'emitter': {'emitter_T2': 0, 'memory_T2': 0, 'QFC_loss': 0}, 'rgs': {'num_branches_half': 2, 'b0': 1, 'b1': 0}}
# 15:46:52 qnpack.APE.allphotonic INFO Iterations: 30
# 15:46:52 qnpack.APE.allphotonic INFO Starting simulation ...
# combo (1, 10)
# 15:46:52 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=1 [30 iters]
# 15:46:52 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 1
# 15:46:54 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:6,meas_mismatch_cnt:0
# 15:46:54 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:46:55 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:12,meas_mismatch_cnt:0
# 15:46:55 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:46:57 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:17,meas_mismatch_cnt:0
# 15:46:57 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (2, 10)
# 15:46:57 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=2 [30 iters]
# 15:46:57 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 2
# 15:46:59 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:5,meas_mismatch_cnt:0
# 15:46:59 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:47:02 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:9,meas_mismatch_cnt:0
# 15:47:02 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:47:04 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:13,meas_mismatch_cnt:0
# 15:47:04 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (3, 10)
# 15:47:04 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=3 [30 iters]
# 15:47:04 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 3
# 15:47:08 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:5,meas_mismatch_cnt:0
# 15:47:08 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:47:11 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:6,meas_mismatch_cnt:0
# 15:47:11 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:47:14 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:9,meas_mismatch_cnt:0
# 15:47:14 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (4, 10)
# 15:47:14 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=4 [30 iters]
# 15:47:14 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 4
# 15:47:19 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:5,meas_mismatch_cnt:0
# 15:47:19 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:47:23 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:9,meas_mismatch_cnt:0
# 15:47:23 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:47:27 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:10,meas_mismatch_cnt:0
# 15:47:27 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# Current memory [MB]: 7.8222 Peak memory [MB]: 7.9855

# %% [markdown]
# # Effect of number of branches in RGS:
# We can see under the ideal situation, the repeater rate is actually decreasing with number of repeaters (QRs). This is because n repeaters would require n+1 BSM nodes, and a repeater chain would succeed only if at least one BSM succeeds on each BSM node. For each BSM, the success probability would involve two photons arriving from the left and right nodes, multiplied by the success probability 0.5 by linear optics BSM:
#
# $P_{BSM}=(1-P_{loss})^2/2$
#
# where $P_{loss}$ is the loss probability of a single photon.
# For a repeater graph state, there are a total number of m BSMs in each BSM node, which corresponds to the parameter `num_branches_half` in the code. The probability of at least one of them succeeds is:
#
# $P_{BSM,\geq1}=1-(1-P_{BSM})^m$
#
# Hence, the probability of having at least one BSM succeeds at each BSM node in the whole repeater chain will decrease with the number of repeaters n:
#
# $P_{BSM,chain}=(P_{BSM,\geq1})^{n+1}$
#
# To solve this problem, we would need to increase the number of branches in the RGS, as shown in the code below.

# %%
#from qnpack.APE.allphotonic import APESimulation

fixed_params = {
    "network": {"photon_loss": 0},
    "emitter":{"emitter_T2":0, "memory_T2":0,"QFC_loss":0},
    "rgs":{"num_branches_half":6,"b0":1,"b1":0}    
}
varying_params = {
    "num_repeaters": [1,2,3,4],
    "distance": [10]
}

sim = APESimulation(fixed_params=fixed_params,
                    varying_params=varying_params,
                    iterations=30,
                    min_successful=0,
                    parameter_file="parameters/scenario1.yml",
                    output_dir="results")
data=sim.start()
sim.plot(final_data=data, show_theo_rate=True, x_axis1="num_repeaters", y_axis1="sim_rate", xlabel1="Number of repeaters", ylabel1="Rate (Hz)",
     label_param1="distance", title1="Rate vs Number of repeaters",
     x_axis2="num_repeaters", y_axis2="fidelity", xlabel2="Number of repeaters", ylabel2="Fidelity",
     label_param2="distance", title2="Fidelity vs Number of repeaters"
     )
sim.finalize()
# Out:
# Updated network.photon_loss: 0.2 -> 0
# Updated emitter.emitter_T2: 3000 -> 0
# Updated emitter.memory_T2: 20000000.0 -> 0
# Updated emitter.QFC_loss: 0 -> 0
# Updated rgs.num_branches_half: 2 -> 6
# Updated rgs.b0: 2 -> 1
# Updated rgs.b1: 1 -> 0
# self.cfg.network.photon_loss 0
# 15:47:30 qnpack.APE.allphotonic INFO Configuration:
# bsm:
#   coupling_efficiency: 0.9
#   detection_window: 3
#   detector_wait_factor: 1.05
#   max_emission_retries: 90
#   system_delay: 0
#   timeout: 40
# clock:
#   HZ: 1000000
#   max_ticks: -1
# emitter:
#   CZ_duration: 100
#   EMIT_PHOTON_duration: 2
#   H_duration: 1
#   INIT_duration: 1
#   MEASURE_duration: 20
#   QFC_loss: 0
#   collection_eff: 0.997
#   detector_eff: 1
#   emitter_T1: 0
#   emitter_T2: 0
#   mem_measure: forced
#   memory_T1: 0
#   memory_T2: 0
#   num_matter_qubits: 7
#   photon_emission_buffer: 1
# network:
#   attenuation_length: 22
#   c_lightspeed: 200000
#   channel_depolar_rate: 0.1
#   init_photon_loss: 0
#   node_c_pos: 0
#   photon_loss: 0
#   proto_sched: 1
#   q_lightspeed: 200000
# rgs:
#   b0: 1
#   b1: 0
#   num_branches_half: 6
# sim:
#   debug: false
#   is_one_end_noise: false
#   iterations: 10
#   min_successful: 0
#   noiseless: false
#   starting_seed: 500000
# spd:
#   detection_window: 2
#
# 15:47:30 qnpack.APE.allphotonic INFO Running simulation with parameters: {'num_repeaters': [1, 2, 3, 4], 'distance': [10]}
# 15:47:30 qnpack.APE.allphotonic INFO Fixed parameters: {'network': {'photon_loss': 0}, 'emitter': {'emitter_T2': 0, 'memory_T2': 0, 'QFC_loss': 0}, 'rgs': {'num_branches_half': 6, 'b0': 1, 'b1': 0}}
# 15:47:30 qnpack.APE.allphotonic INFO Iterations: 30
# 15:47:30 qnpack.APE.allphotonic INFO Starting simulation ...
# combo (1, 10)
# 15:47:30 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=1 [30 iters]
# 15:47:30 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 1
# 15:47:35 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:10,meas_mismatch_cnt:0
# 15:47:35 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:47:39 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:19,meas_mismatch_cnt:0
# 15:47:39 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:47:44 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:28,meas_mismatch_cnt:0
# 15:47:44 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (2, 10)
# 15:47:44 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=2 [30 iters]
# 15:47:44 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 2
# 15:47:51 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:10,meas_mismatch_cnt:0
# 15:47:51 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:47:59 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:20,meas_mismatch_cnt:0
# 15:47:59 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:48:06 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:29,meas_mismatch_cnt:0
# 15:48:06 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (3, 10)
# 15:48:06 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=3 [30 iters]
# 15:48:06 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 3
# 15:48:17 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:8,meas_mismatch_cnt:0
# 15:48:17 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:48:28 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:18,meas_mismatch_cnt:0
# 15:48:28 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:48:40 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:27,meas_mismatch_cnt:0
# 15:48:40 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (4, 10)
# 15:48:40 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=4 [30 iters]
# 15:48:40 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 4
# 15:48:53 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:8,meas_mismatch_cnt:0
# 15:48:53 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:49:07 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:16,meas_mismatch_cnt:0
# 15:49:07 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:49:21 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:26,meas_mismatch_cnt:0
# 15:49:21 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# Current memory [MB]: 8.8308 Peak memory [MB]: 8.9906

# %% [markdown]
# # Effect of photon loss
# After using RGS with more branches, since $P_{BSM,\geq1}$ would be increased, having more repeaters can actually increase the repeater rate now because the node-to-node distance is much shorter for the transmission of photon.
# Next, we introduce photon loss due to fiber attenuation and see how the repeater performance will be affected. The photon loss probability scales exponentially with length L of the quantum channel:
# $P_{loss}=10^{-\alpha/L}$ where $\alpha$ is the signal attenuation rate in 0.2dB/km. The following code introduces photon loss under the same repeater setting from above.

# %%
from qnpack.APE.allphotonic import APESimulation

fixed_params = {
    "network": {"photon_loss": 0.2},
    "emitter":{"emitter_T2":0, "memory_T2":0,"QFC_loss":0},
    "rgs":{"num_branches_half":6,"b0":1,"b1":0}    
}
varying_params = {
    "num_repeaters": [1,2,3,4],
    "distance": [10]
}

sim = APESimulation(fixed_params=fixed_params,
                    varying_params=varying_params,
                    iterations=30,
                    min_successful=0,
                    parameter_file="parameters/scenario1.yml",
                    output_dir="results")
data=sim.start()
sim.plot(final_data=data, show_theo_rate=True, x_axis1="num_repeaters", y_axis1="sim_rate", xlabel1="Number of repeaters", ylabel1="Rate (Hz)",
     label_param1="distance", title1="Rate vs Number of repeaters",
     x_axis2="num_repeaters", y_axis2="fidelity", xlabel2="Number of repeaters", ylabel2="Fidelity",
     label_param2="distance", title2="Fidelity vs Number of repeaters"
     )
sim.finalize()
# Out:
# Updated network.photon_loss: 0.2 -> 0.2
# Updated emitter.emitter_T2: 3000 -> 0
# Updated emitter.memory_T2: 20000000.0 -> 0
# Updated emitter.QFC_loss: 0 -> 0
# Updated rgs.num_branches_half: 2 -> 6
# Updated rgs.b0: 2 -> 1
# Updated rgs.b1: 1 -> 0
# self.cfg.network.photon_loss 0.2
# 15:49:24 qnpack.APE.allphotonic INFO Configuration:
# bsm:
#   coupling_efficiency: 0.9
#   detection_window: 3
#   detector_wait_factor: 1.05
#   max_emission_retries: 90
#   system_delay: 0
#   timeout: 40
# clock:
#   HZ: 1000000
#   max_ticks: -1
# emitter:
#   CZ_duration: 100
#   EMIT_PHOTON_duration: 2
#   H_duration: 1
#   INIT_duration: 1
#   MEASURE_duration: 20
#   QFC_loss: 0
#   collection_eff: 0.997
#   detector_eff: 1
#   emitter_T1: 0
#   emitter_T2: 0
#   mem_measure: forced
#   memory_T1: 0
#   memory_T2: 0
#   num_matter_qubits: 7
#   photon_emission_buffer: 1
# network:
#   attenuation_length: 22
#   c_lightspeed: 200000
#   channel_depolar_rate: 0.1
#   init_photon_loss: 0
#   node_c_pos: 0
#   photon_loss: 0.2
#   proto_sched: 1
#   q_lightspeed: 200000
# rgs:
#   b0: 1
#   b1: 0
#   num_branches_half: 6
# sim:
#   debug: false
#   is_one_end_noise: false
#   iterations: 10
#   min_successful: 0
#   noiseless: false
#   starting_seed: 500000
# spd:
#   detection_window: 2
#
# 15:49:24 qnpack.APE.allphotonic INFO Running simulation with parameters: {'num_repeaters': [1, 2, 3, 4], 'distance': [10]}
# 15:49:24 qnpack.APE.allphotonic INFO Fixed parameters: {'network': {'photon_loss': 0.2}, 'emitter': {'emitter_T2': 0, 'memory_T2': 0, 'QFC_loss': 0}, 'rgs': {'num_branches_half': 6, 'b0': 1, 'b1': 0}}
# 15:49:24 qnpack.APE.allphotonic INFO Iterations: 30
# 15:49:24 qnpack.APE.allphotonic INFO Starting simulation ...
# combo (1, 10)
# 15:49:24 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=1 [30 iters]
# 15:49:24 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 1
# 15:49:28 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:2,meas_mismatch_cnt:0
# 15:49:28 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:49:32 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:5,meas_mismatch_cnt:0
# 15:49:32 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:49:36 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:5,meas_mismatch_cnt:0
# 15:49:36 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (2, 10)
# 15:49:36 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=2 [30 iters]
# 15:49:36 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 2
# 15:49:44 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:0,meas_mismatch_cnt:0
# 15:49:44 qnpack.APE.allphotonic INFO 		fidelity: nan
# /home/ottochan/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /home/ottochan/.local/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 15:49:51 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:1,meas_mismatch_cnt:0
# 15:49:51 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# 15:49:58 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:3,meas_mismatch_cnt:0
# 15:49:58 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (3, 10)
# 15:49:58 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=3 [30 iters]
# 15:49:58 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 3
# 15:50:08 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:0,meas_mismatch_cnt:0
# 15:50:08 qnpack.APE.allphotonic INFO 		fidelity: nan
# 15:50:18 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:0,meas_mismatch_cnt:0
# 15:50:18 qnpack.APE.allphotonic INFO 		fidelity: nan
# 15:50:27 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:0,meas_mismatch_cnt:0
# 15:50:27 qnpack.APE.allphotonic INFO 		fidelity: nan
# combo (4, 10)
# 15:50:27 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=4 [30 iters]
# 15:50:27 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 4
# 15:50:39 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:0,meas_mismatch_cnt:0
# 15:50:39 qnpack.APE.allphotonic INFO 		fidelity: nan
# 15:50:52 qnpack.APE.allphotonic INFO 		cnt:20,successful_cnt:0,meas_mismatch_cnt:0
# 15:50:52 qnpack.APE.allphotonic INFO 		fidelity: nan
# 15:51:04 qnpack.APE.allphotonic INFO 		cnt:30,successful_cnt:0,meas_mismatch_cnt:0
# 15:51:04 qnpack.APE.allphotonic INFO 		fidelity: nan
# Current memory [MB]: 7.4107 Peak memory [MB]: 7.5494

# %% [markdown]
# # Tree-encoded RGS and fault tolerent measurement
# We can see that the repeater rate decreases drastically when fiber loss is introduced, and having more repeaters makes the rate worse again! This is because the RGS scheme requires all the measurement of the core qubits to be successful. In the RGS, each core qubit plays the role of the trapped ion. All the core qubits are fully connected with one another in the graph. This is as if we perform the DBSM of trapped-ion repeater in advance, and perform Bell State measurement between photons emitted by trapped-ion afterwards. But in the APE case, the leaf qubits play the role of those photons emitted by trapped-ions. To understand the price we need to pay to replace the trapped-ion memory qubits by the core photons in the RGS, the success probability of receiving all the 2m core qubits in each BSM node is
#
# $P_{all\: core}=(1-P_{loss})^{2m}$
#
# and it also scales up with the number of repeaters n:
#
# $P_{all\: core,chain}=(P_{all\: core})^{n+1}$
#
# Hence, taking into account the probalistic BSM, the total success probablity for the whole repeater chain becomes
#
# $P_{chain}=P_{BSM,chain}*P_{all\: core,chain}$
#
# The requirement of all core qubits to be successfully measured is formiddable once m and n become large. This gives the motivation of introducing encoding to protect the core qubits. In the RGS, each core qubit is encoded by a tree, as shown in the following diagram:
#
# <img src="./images/GS_tree_encoding.png" width="40%"><br>
#
# The tree encoding uses a large number of photons to encode each core qubit, and the redunduncy provides protection against the loss of a certain subset of those photons. The decoding details of the tree encoding is implemented in the `NodeProtocol` of the control node in NetSquid, following the scheme in Physical review letters, 97(12), 120501. The code below shows how we can set up the 2-level tree-encoding of RGS, with a total of 12 branches, each consisted of a tree with parameters $b_0=6$ and $b_1=3$. Notice that this would require longer time for the simulation to run, becasue each (6,6,3) RGS is consisted of 300 photonic qubits, and for 4 repeaters, there would be over a thousand photonic qubits. This is handled by the `StabRepr` in NetSquid.

# %%
from qnpack.APE.allphotonic import APESimulation

fixed_params = {
    "network": {"photon_loss": 0.2},
    "emitter":{"emitter_T2":0, "memory_T2":0,"QFC_loss":0},    
    "rgs":{"num_branches_half":6,"b0":6,"b1":3}
}
varying_params = {
    "num_repeaters": [1,2,3,4],
    "distance": [10]
}

sim = APESimulation(fixed_params=fixed_params,
                    varying_params=varying_params,
                    iterations=10,
                    min_successful=0,
                    parameter_file="parameters/scenario1.yml",
                    output_dir="results")
data=sim.start()
sim.plot(final_data=data, show_theo_rate=True, x_axis1="num_repeaters", y_axis1="sim_rate", xlabel1="Number of repeaters", ylabel1="Rate (Hz)",
     label_param1="distance", title1="Rate vs Number of repeaters",
     x_axis2="num_repeaters", y_axis2="fidelity", xlabel2="Number of repeaters", ylabel2="Fidelity",
     label_param2="distance", title2="Fidelity vs Number of repeaters"
     )
sim.finalize()
# Out:
# Updated network.photon_loss: 0.2 -> 0.2
# Updated emitter.emitter_T2: 3000 -> 0
# Updated emitter.memory_T2: 20000000.0 -> 0
# Updated emitter.QFC_loss: 0 -> 0
# Updated rgs.num_branches_half: 2 -> 6
# Updated rgs.b0: 2 -> 6
# Updated rgs.b1: 1 -> 3
# self.cfg.network.photon_loss 0.2
# 15:51:06 qnpack.APE.allphotonic INFO Configuration:
# bsm:
#   coupling_efficiency: 0.9
#   detection_window: 3
#   detector_wait_factor: 1.05
#   max_emission_retries: 90
#   system_delay: 0
#   timeout: 40
# clock:
#   HZ: 1000000
#   max_ticks: -1
# emitter:
#   CZ_duration: 100
#   EMIT_PHOTON_duration: 2
#   H_duration: 1
#   INIT_duration: 1
#   MEASURE_duration: 20
#   QFC_loss: 0
#   collection_eff: 0.997
#   detector_eff: 1
#   emitter_T1: 0
#   emitter_T2: 0
#   mem_measure: forced
#   memory_T1: 0
#   memory_T2: 0
#   num_matter_qubits: 7
#   photon_emission_buffer: 1
# network:
#   attenuation_length: 22
#   c_lightspeed: 200000
#   channel_depolar_rate: 0.1
#   init_photon_loss: 0
#   node_c_pos: 0
#   photon_loss: 0.2
#   proto_sched: 1
#   q_lightspeed: 200000
# rgs:
#   b0: 6
#   b1: 3
#   num_branches_half: 6
# sim:
#   debug: false
#   is_one_end_noise: false
#   iterations: 10
#   min_successful: 0
#   noiseless: false
#   starting_seed: 500000
# spd:
#   detection_window: 2
#
# 15:51:07 qnpack.APE.allphotonic INFO Running simulation with parameters: {'num_repeaters': [1, 2, 3, 4], 'distance': [10]}
# 15:51:07 qnpack.APE.allphotonic INFO Fixed parameters: {'network': {'photon_loss': 0.2}, 'emitter': {'emitter_T2': 0, 'memory_T2': 0, 'QFC_loss': 0}, 'rgs': {'num_branches_half': 6, 'b0': 6, 'b1': 3}}
# 15:51:07 qnpack.APE.allphotonic INFO Iterations: 10
# 15:51:07 qnpack.APE.allphotonic INFO Starting simulation ...
# combo (1, 10)
# 15:51:07 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=1 [10 iters]
# 15:51:07 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 1
# 15:51:30 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:9,meas_mismatch_cnt:0
# 15:51:30 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (2, 10)
# 15:51:30 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=2 [10 iters]
# 15:51:30 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 2
# 15:52:19 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:10,meas_mismatch_cnt:0
# 15:52:19 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (3, 10)
# 15:52:19 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=3 [10 iters]
# 15:52:19 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 3
# 15:53:35 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:10,meas_mismatch_cnt:0
# 15:53:35 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (4, 10)
# 15:53:35 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=4 [10 iters]
# 15:53:35 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 4
# 15:55:16 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:8,meas_mismatch_cnt:0
# 15:55:16 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# Current memory [MB]: 7.4464 Peak memory [MB]: 12.2815

# %% [markdown]
# # Effect of quantum emitter coherence time on fidelity:
# With the tree encoding, the repeater rate has increased almost to the level before we introduced photon loss. In general, a larger encoding would require a longer RGS generation time, but has a better ability to protect against photon loss, so a larger RGS does not necessarily give better performance. In addition, there are also huge resource overhead for generating such a large entangled photonic state. Inside NetSquid, we simulate the deterministic approach of graph state generation by sequentially stimulating the quantum emitter in each APE QR. The major source of noise comes from the decoherence effect of the quantum emitter during graph state generation. In the code below, we investigate how the docoherence effect impact the fidelity of the final entangled Bell state across the two ends, with the coherence time of the quantum dot emitter set to $3\mu s$, and the coherence time of the nuclear spin memory set to $20ms$.

# %%
from qnpack.APE.allphotonic import APESimulation

fixed_params = {
    "network": {"photon_loss": 0.2},
    "emitter":{"emitter_T2":3000, "memory_T2":20e+06,"QFC_loss":0},    
    "rgs":{"num_branches_half":6,"b0":6,"b1":3}
}
varying_params = {
    "num_repeaters": [1,2,3,4],
    "distance": [10]
}

sim = APESimulation(fixed_params=fixed_params,
                    varying_params=varying_params,
                    iterations=10,
                    min_successful=0,
                    parameter_file="parameters/scenario1.yml",
                    output_dir="results")
data=sim.start()
sim.plot(final_data=data, show_theo_rate=True, x_axis1="num_repeaters", y_axis1="sim_rate", xlabel1="Number of repeaters", ylabel1="Rate (Hz)",
     label_param1="distance", title1="Rate vs Number of repeaters",
     x_axis2="num_repeaters", y_axis2="fidelity", xlabel2="Number of repeaters", ylabel2="Fidelity",
     label_param2="distance", title2="Fidelity vs Number of repeaters"
     )
sim.finalize()
# Out:
# Updated network.photon_loss: 0.2 -> 0.2
# Updated emitter.emitter_T2: 3000 -> 3000
# Updated emitter.memory_T2: 20000000.0 -> 20000000.0
# Updated emitter.QFC_loss: 0 -> 0
# Updated rgs.num_branches_half: 2 -> 6
# Updated rgs.b0: 2 -> 6
# Updated rgs.b1: 1 -> 3
# self.cfg.network.photon_loss 0.2
# 15:55:19 qnpack.APE.allphotonic INFO Configuration:
# bsm:
#   coupling_efficiency: 0.9
#   detection_window: 3
#   detector_wait_factor: 1.05
#   max_emission_retries: 90
#   system_delay: 0
#   timeout: 40
# clock:
#   HZ: 1000000
#   max_ticks: -1
# emitter:
#   CZ_duration: 100
#   EMIT_PHOTON_duration: 2
#   H_duration: 1
#   INIT_duration: 1
#   MEASURE_duration: 20
#   QFC_loss: 0
#   collection_eff: 0.997
#   detector_eff: 1
#   emitter_T1: 0
#   emitter_T2: 3000
#   mem_measure: forced
#   memory_T1: 0
#   memory_T2: 20000000.0
#   num_matter_qubits: 7
#   photon_emission_buffer: 1
# network:
#   attenuation_length: 22
#   c_lightspeed: 200000
#   channel_depolar_rate: 0.1
#   init_photon_loss: 0
#   node_c_pos: 0
#   photon_loss: 0.2
#   proto_sched: 1
#   q_lightspeed: 200000
# rgs:
#   b0: 6
#   b1: 3
#   num_branches_half: 6
# sim:
#   debug: false
#   is_one_end_noise: false
#   iterations: 10
#   min_successful: 0
#   noiseless: false
#   starting_seed: 500000
# spd:
#   detection_window: 2
#
# 15:55:19 qnpack.APE.allphotonic INFO Running simulation with parameters: {'num_repeaters': [1, 2, 3, 4], 'distance': [10]}
# 15:55:19 qnpack.APE.allphotonic INFO Fixed parameters: {'network': {'photon_loss': 0.2}, 'emitter': {'emitter_T2': 3000, 'memory_T2': 20000000.0, 'QFC_loss': 0}, 'rgs': {'num_branches_half': 6, 'b0': 6, 'b1': 3}}
# 15:55:19 qnpack.APE.allphotonic INFO Iterations: 10
# 15:55:19 qnpack.APE.allphotonic INFO Starting simulation ...
# combo (1, 10)
# 15:55:19 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=1 [10 iters]
# 15:55:19 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 1
# 15:55:45 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:9,meas_mismatch_cnt:0
# 15:55:45 qnpack.APE.allphotonic INFO 		fidelity: 0.7777777777777778
# combo (2, 10)
# 15:55:45 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=2 [10 iters]
# 15:55:45 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 2
# 15:56:38 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:10,meas_mismatch_cnt:0
# 15:56:38 qnpack.APE.allphotonic INFO 		fidelity: 0.8
# combo (3, 10)
# 15:56:38 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=3 [10 iters]
# 15:56:38 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 3
# 15:57:59 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:9,meas_mismatch_cnt:0
# 15:57:59 qnpack.APE.allphotonic INFO 		fidelity: 0.7777777777777778
# combo (4, 10)
# 15:57:59 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=4 [10 iters]
# 15:57:59 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 4
# 15:59:48 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:8,meas_mismatch_cnt:0
# 15:59:48 qnpack.APE.allphotonic INFO 		fidelity: 0.75
# Current memory [MB]: 7.6859 Peak memory [MB]: 12.9694

# %% [markdown]
# You can see the entanglement fidelity is affected by the emitter and memory decoherence. In general, the fidelity will decrease with the number of repeaters since each additional repeater will introduce an extra graph state genearation process. The RGS has certain error correcting ability by taking majority votes among the measurement outcomes of all the subtrees. A larger RGS has a better error correction ability but also requires longer genration time and hence receives more decohenrence noise from the emitter. In overall, the optimized RGS size would be a complicated function of the total distance, number of repeaters, RGS generation circuit, all noise parameters and loss parameters.

# %% [markdown]
# # Exercise: Comparing different RGS sizes
# Under the quantum repeater network configuration with total distance 10km, fiber attenuation rate=0.2dB/km, emitter coherence time=$3\mu s$ and memory decoherece time=$20ms$, find the optimal RGS size among the given parameters:
#
# | m | $b_0$ | $b_1$ |
# |---|---|---|
# | 2 | 18 | 1 |
# | 3 | 6 | 3 |
# | 4 | 4 | 3 |
#
# Task:
# For each of the rgs parameters, compute the rate and fidelity and see which gives the best value.

# %%
from qnpack.APE.allphotonic import APESimulation

fixed_params = {
    "network": {"photon_loss": 0.2},
    "emitter":{"emitter_T2":3000, "memory_T2":20e+06,"QFC_loss":0},    
    #Fill in the rgs parameters that you want to calculate here
}
varying_params = {
    "num_repeaters": [1,2,3,4],
    "distance": [10]
}

sim = APESimulation(fixed_params=fixed_params,
                    varying_params=varying_params,
                    iterations=10,
                    min_successful=0,
                    parameter_file="parameters/scenario1.yml",
                    output_dir="results")
data=sim.start()
sim.plot(final_data=data, show_theo_rate=True, x_axis1="num_repeaters", y_axis1="sim_rate", xlabel1="Number of repeaters", ylabel1="Rate (Hz)",
     label_param1="distance", title1="Rate vs Number of repeaters",
     x_axis2="num_repeaters", y_axis2="fidelity", xlabel2="Number of repeaters", ylabel2="Fidelity",
     label_param2="distance", title2="Fidelity vs Number of repeaters"
     )
sim.finalize()
# Out:
# Updated network.photon_loss: 0.2 -> 0.2
# Updated emitter.emitter_T2: 3000 -> 3000
# Updated emitter.memory_T2: 20000000.0 -> 20000000.0
# Updated emitter.QFC_loss: 0 -> 0
# self.cfg.network.photon_loss 0.2
# 15:59:51 qnpack.APE.allphotonic INFO Configuration:
# bsm:
#   coupling_efficiency: 0.9
#   detection_window: 3
#   detector_wait_factor: 1.05
#   max_emission_retries: 90
#   system_delay: 0
#   timeout: 40
# clock:
#   HZ: 1000000
#   max_ticks: -1
# emitter:
#   CZ_duration: 100
#   EMIT_PHOTON_duration: 2
#   H_duration: 1
#   INIT_duration: 1
#   MEASURE_duration: 20
#   QFC_loss: 0
#   collection_eff: 0.997
#   detector_eff: 1
#   emitter_T1: 0
#   emitter_T2: 3000
#   mem_measure: forced
#   memory_T1: 0
#   memory_T2: 20000000.0
#   num_matter_qubits: 7
#   photon_emission_buffer: 1
# network:
#   attenuation_length: 22
#   c_lightspeed: 200000
#   channel_depolar_rate: 0.1
#   init_photon_loss: 0
#   node_c_pos: 0
#   photon_loss: 0.2
#   proto_sched: 1
#   q_lightspeed: 200000
# rgs:
#   b0: 2
#   b1: 1
#   num_branches_half: 2
# sim:
#   debug: false
#   is_one_end_noise: false
#   iterations: 10
#   min_successful: 0
#   noiseless: false
#   starting_seed: 500000
# spd:
#   detection_window: 2
#
# 15:59:51 qnpack.APE.allphotonic INFO Running simulation with parameters: {'num_repeaters': [1, 2, 3, 4], 'distance': [10]}
# 15:59:51 qnpack.APE.allphotonic INFO Fixed parameters: {'network': {'photon_loss': 0.2}, 'emitter': {'emitter_T2': 3000, 'memory_T2': 20000000.0, 'QFC_loss': 0}}
# 15:59:51 qnpack.APE.allphotonic INFO Iterations: 10
# 15:59:51 qnpack.APE.allphotonic INFO Starting simulation ...
# combo (1, 10)
# 15:59:51 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=1 [10 iters]
# 15:59:51 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 1
# 15:59:54 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:4,meas_mismatch_cnt:0
# 15:59:54 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# combo (2, 10)
# 15:59:54 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=2 [10 iters]
# 15:59:54 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 2
# 15:59:59 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:3,meas_mismatch_cnt:0
# 15:59:59 qnpack.APE.allphotonic INFO 		fidelity: 0.6666666666666666
# combo (3, 10)
# 15:59:59 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=3 [10 iters]
# 15:59:59 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 3
# 16:00:05 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:2,meas_mismatch_cnt:0
# 16:00:05 qnpack.APE.allphotonic INFO 		fidelity: 0.5
# combo (4, 10)
# 16:00:05 qnpack.APE.allphotonic INFO 	Running params: distance=10, num_repeaters=4 [10 iters]
# 16:00:05 qnpack.APE.allphotonic INFO 		total_distance: 10, num_repeater: 4
# 16:00:13 qnpack.APE.allphotonic INFO 		cnt:10,successful_cnt:1,meas_mismatch_cnt:0
# 16:00:13 qnpack.APE.allphotonic INFO 		fidelity: 1.0
# Current memory [MB]: 6.5707 Peak memory [MB]: 6.7766
