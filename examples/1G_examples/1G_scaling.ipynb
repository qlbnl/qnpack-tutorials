# %% [markdown]
# # 1G Repeater Network with >1 Repeaters
#
# This example will demonstrate how to use QNPack to simulate a quantum network repeater chain using a multiple quantum repeaters (QRs).
#
# <img src="./images/1g_scale.png" width="100%"><br>

# %% [markdown]
# ### Varying network size to max capability

# %%
from qnpack.oneG.iontrap import IonTrapSimulation
fixed_params = {
    "photon_loss": 0.2,
    "coherence_time": 60000000, #ns
}

varying_params = {
    "num_repeaters": [2, 4, 6, 8],
    "distance": [20],
}

sim = IonTrapSimulation(fixed_params=fixed_params, varying_params=varying_params,
                        iterations=10,
                        parameter_file="parameters/noiseless.yml",
                        output_dir="results")
data = sim.start()
sim.plot(final_data=data, x_axis1="num_repeaters", y_axis1="fidelity",  xlabel1="Number of Repeaters", ylabel1="Fidelity",
         label_param1="distance", title1="Fidelity vs Number of Repeaters",
         x_axis2="num_repeaters", y_axis2="rate",  xlabel2="Number of Repeaters", ylabel2="Rate (Hz)",
         label_param2="distance", title2="Rate vs Number of Repeaters")
# Out:
# 20:30:21 qnpack.oneG.iontrap INFO Configuration:
# bsm:
#   coupling_efficiency: 1
#   detection_window: 4320000.0
#   detector_wait_factor: 1.05
#   max_emission_retries: 30
#   system_delay: 0
#   timeout: 40
# clock:
#   HZ: 1000000
#   max_ticks: -1
# ion_trap:
#   coherence_time: 0
#   collection_efficiency: 1
#   decay_rate: 11490000
#   doppler_sim_time: 4000
#   emission_duration: 7220000
#   emission_fidelity: 1
#   gs_prob: 1
#   init_depolar_prob: 0
#   init_sim_time: 30
#   initial_mean_excitation_number: 1
#   initial_velocity: 1.0
#   ion_mass: 6.64e-26
#   lamb_dicke_parameter: 0.1
#   laser_wavelength: 4.0e-07
#   measurement_duration: 5000
#   ms_depolar_prob: 0.0
#   ms_pi_over_2_duration: 119000
#   noise_model: 0
#   oscillation_frequency: 1000000
#   pump_sim_time: 20
#   rabi_frequency: 22000000
#   raman_ex_sim_time: 150
#   resonant_frequency: 10000000
#   retry_duration: 75000
#   sideband_sim_time: 3000
#   spin_echo_sim_time: 12
#   x_depolar_prob: 0.0
#   x_gate_duration: 5000
#   z_depolar_prob: 0.0
#   z_gate_duration: 5000
# network:
#   c_lightspeed: 200000
#   channel_depolar_rate: 0.0
#   init_photon_loss: 0.0
#   node_c_pos: 0
#   photon_loss: 0.0
#   proto_sched: 1
#   q_lightspeed: 200000
# sim:
#   debug: false
#   iterations: 10
#
# 20:30:21 qnpack.oneG.iontrap INFO Running simulation with parameters: {'num_repeaters': [2, 4, 6, 8], 'distance': [20]}
# 20:30:21 qnpack.oneG.iontrap INFO Fixed parameters: {'photon_loss': 0.2, 'coherence_time': 60000000}
# 20:30:21 qnpack.oneG.iontrap INFO Iterations: 10
# 20:30:21 qnpack.oneG.iontrap INFO Running simulation with parameters: {'num_repeaters': 2, 'distance': 20}
# 20:30:23 qnpack.oneG.iontrap INFO 	  Fidelities: [0.71, 1.0, 1.0, 0.97, 0.96, 1.0, 0.97, 0.99, 1.0, 1.0]
# 20:30:23 qnpack.oneG.iontrap INFO 	  Rate of Entanglement: 62.82, with total time: 0.15919100000000003 and number of success: 10
# 20:30:23 qnpack.oneG.iontrap INFO 	  Mean Fidelity: 0.959558970078224
# 20:30:23 qnpack.oneG.iontrap INFO Running simulation with parameters: {'num_repeaters': 4, 'distance': 20}
# 20:30:26 qnpack.oneG.iontrap INFO 	  Fidelities: [0.98, 0.99, 0.81, 0.76, 1.0, 0.94, 0.97, 0.83, 1.0, 1.0]
# 20:30:26 qnpack.oneG.iontrap INFO 	  Rate of Entanglement: 62.86, with total time: 0.15909350000000005 and number of success: 10
# 20:30:26 qnpack.oneG.iontrap INFO 	  Mean Fidelity: 0.9271858813154801
# 20:30:26 qnpack.oneG.iontrap INFO Running simulation with parameters: {'num_repeaters': 6, 'distance': 20}
# 20:30:30 qnpack.oneG.iontrap INFO 	  Fidelities: [0.92, 0.92, 0.98, 0.99, 1.0, 0.63, 0.42, 0.85, 0.87, 1.0]
# 20:30:30 qnpack.oneG.iontrap INFO 	  Rate of Entanglement: 62.53, with total time: 0.1599157142857143 and number of success: 10
# 20:30:30 qnpack.oneG.iontrap INFO 	  Mean Fidelity: 0.8589973302426023
# 20:30:30 qnpack.oneG.iontrap INFO Running simulation with parameters: {'num_repeaters': 8, 'distance': 20}
# 20:30:37 qnpack.oneG.iontrap INFO 	  Fidelities: [0.89, 0.92, 0.89, 1.0, 0.8, 0.99, 1.0, 0.71, 0.98, 0.91]
# 20:30:37 qnpack.oneG.iontrap INFO 	  Rate of Entanglement: 62.89, with total time: 0.15902033333333337 and number of success: 10
# 20:30:37 qnpack.oneG.iontrap INFO 	  Mean Fidelity: 0.9087037003993661

# %% [markdown]
# Results for fidleity and rate with varying network lengths for 1500 iterations
#
# <img src="./images/1g_fid_rate.png" width="100%"><br>

# %% [markdown]
# ### Success count based on overall photon loss and network length

# %%
from qnpack.oneG.iontrap import IonTrapSimulation
fixed_params = {
    "photon_loss": 0.2,
    "init_photon_loss": 0.7,
    "coherence_time": 60000000, #ns
}

varying_params = {
    "num_repeaters": [1],
    "distance": [200],
}

sim = IonTrapSimulation(fixed_params=fixed_params, varying_params=varying_params,
                        iterations=10,
                        parameter_file="parameters/noiseless.yml",
                        output_dir="results")
data = sim.start()
sim.plot(final_data=data, x_axis1="num_repeaters", y_axis1="fidelity",  xlabel1="Number of Repeaters", ylabel1="Fidelity",
         label_param1="distance", title1="Fidelity vs Number of Repeaters",
         x_axis2="num_repeaters", y_axis2="rate",  xlabel2="Number of Repeaters", ylabel2="Rate (Hz)",
         label_param2="distance", title2="Rate vs Number of Repeaters")
# Out:
# 20:32:41 qnpack.oneG.iontrap INFO Configuration:
# bsm:
#   coupling_efficiency: 1
#   detection_window: 4320000.0
#   detector_wait_factor: 1.05
#   max_emission_retries: 30
#   system_delay: 0
#   timeout: 40
# clock:
#   HZ: 1000000
#   max_ticks: -1
# ion_trap:
#   coherence_time: 0
#   collection_efficiency: 1
#   decay_rate: 11490000
#   doppler_sim_time: 4000
#   emission_duration: 7220000
#   emission_fidelity: 1
#   gs_prob: 1
#   init_depolar_prob: 0
#   init_sim_time: 30
#   initial_mean_excitation_number: 1
#   initial_velocity: 1.0
#   ion_mass: 6.64e-26
#   lamb_dicke_parameter: 0.1
#   laser_wavelength: 4.0e-07
#   measurement_duration: 5000
#   ms_depolar_prob: 0.0
#   ms_pi_over_2_duration: 119000
#   noise_model: 0
#   oscillation_frequency: 1000000
#   pump_sim_time: 20
#   rabi_frequency: 22000000
#   raman_ex_sim_time: 150
#   resonant_frequency: 10000000
#   retry_duration: 75000
#   sideband_sim_time: 3000
#   spin_echo_sim_time: 12
#   x_depolar_prob: 0.0
#   x_gate_duration: 5000
#   z_depolar_prob: 0.0
#   z_gate_duration: 5000
# network:
#   c_lightspeed: 200000
#   channel_depolar_rate: 0.0
#   init_photon_loss: 0.0
#   node_c_pos: 0
#   photon_loss: 0.0
#   proto_sched: 1
#   q_lightspeed: 200000
# sim:
#   debug: false
#   iterations: 10
#
# 20:32:41 qnpack.oneG.iontrap INFO Running simulation with parameters: {'num_repeaters': [1], 'distance': [200]}
# 20:32:41 qnpack.oneG.iontrap INFO Fixed parameters: {'photon_loss': 0.2, 'init_photon_loss': 0.7, 'coherence_time': 60000000}
# 20:32:41 qnpack.oneG.iontrap INFO Iterations: 10
# 20:32:41 qnpack.oneG.iontrap INFO Running simulation with parameters: {'num_repeaters': 1, 'distance': 200}
# 20:32:41 qnpack.oneG.lib.protocols WARNING CP: BSM detection was not successful within 30 retries for node_bsm1
# 20:32:41 qnpack.oneG.iontrap WARNING KeyError: Fidelity column missing, skipping iteration
# 20:32:42 qnpack.oneG.lib.protocols WARNING CP: BSM detection was not successful within 30 retries for node_bsm1
# 20:32:42 qnpack.oneG.iontrap WARNING KeyError: Fidelity column missing, skipping iteration
# 20:32:43 qnpack.oneG.lib.protocols WARNING CP: BSM detection was not successful within 30 retries for node_bsm1
# 20:32:43 qnpack.oneG.iontrap WARNING KeyError: Fidelity column missing, skipping iteration
# 20:32:43 qnpack.oneG.lib.protocols WARNING CP: BSM detection was not successful within 30 retries for node_bsm1
# 20:32:43 qnpack.oneG.iontrap WARNING KeyError: Fidelity column missing, skipping iteration
# 20:32:44 qnpack.oneG.lib.protocols WARNING CP: BSM detection was not successful within 30 retries for node_bsm1
# 20:32:44 qnpack.oneG.iontrap WARNING KeyError: Fidelity column missing, skipping iteration
# 20:32:44 qnpack.oneG.lib.protocols WARNING CP: BSM detection was not successful within 30 retries for node_bsm1
# 20:32:44 qnpack.oneG.iontrap WARNING KeyError: Fidelity column missing, skipping iteration
# 20:32:45 qnpack.oneG.lib.protocols WARNING CP: BSM detection was not successful within 30 retries for node_bsm1
# 20:32:45 qnpack.oneG.iontrap WARNING KeyError: Fidelity column missing, skipping iteration
# 20:32:45 qnpack.oneG.lib.protocols WARNING CP: BSM detection was not successful within 30 retries for node_bsm1
# 20:32:45 qnpack.oneG.iontrap WARNING KeyError: Fidelity column missing, skipping iteration
# 20:32:46 qnpack.oneG.lib.protocols WARNING CP: BSM detection was not successful within 30 retries for node_bsm1
# 20:32:46 qnpack.oneG.iontrap WARNING KeyError: Fidelity column missing, skipping iteration
# 20:32:46 qnpack.oneG.lib.protocols WARNING CP: BSM detection was not successful within 30 retries for node_bsm1
# 20:32:46 qnpack.oneG.iontrap WARNING KeyError: Fidelity column missing, skipping iteration
# 20:32:46 qnpack.oneG.iontrap WARNING KeyError: No valid fidelities
# 20:32:46 qnpack.oneG.iontrap INFO 	  Rate of Entanglement: 0, with total time: 0.2716074999999999 and number of success: 0
# 20:32:46 qnpack.oneG.iontrap INFO 	  Mean Fidelity: 0.0
